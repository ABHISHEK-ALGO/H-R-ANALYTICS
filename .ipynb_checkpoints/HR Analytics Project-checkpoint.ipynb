# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Importing the Dataset

# %%
df_emp = pd.read_csv("HR_enhanced.csv")
df_emp.head(3)
# Out:
#   Employee ID First Name Last Name  Gender     State         City  \
# 0      E10000      Aaron      Soto  Female   Florida        Tampa
# 1      E10001      Bruce   Estrada  Female  Illinois   Naperville
# 2      E10002      Linda     Wells    Male  Illinois  Springfield
#
#               Job Title Education Level  Birth Date   Hire Date  ...  \
# 0  Sales Representative      Bachelor's  24-08-1984  25-07-2021  ...
# 1        Sales Director        Master's  30-04-1985  28-08-2019  ...
# 2        Sales Director        Master's  03-02-1972  29-10-2019  ...
#
#   Department  promotion_last_5years satisfaction_level  last_evaluation  \
# 0      sales                      0               0.38             0.53
# 1      sales                      0               0.80             0.86
# 2      sales                      0               0.11             0.88
#
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# ...

# %%
pd.set_option('display.max_rows', 20)

# %%
df_emp
# Out:
#       Employee ID First Name Last Name  Gender       State         City  \
# 0          E10000      Aaron      Soto  Female     Florida        Tampa
# 1          E10001      Bruce   Estrada  Female    Illinois   Naperville
# 2          E10002      Linda     Wells    Male    Illinois  Springfield
# 3          E10003     Austin   Roberts    Male    New York      Buffalo
# 4          E10004    Tiffany     Mason  Female     Florida        Miami
# ...           ...        ...       ...     ...         ...          ...
# 14994      E24994     Alexis   Schultz  Female       Texas       Dallas
# 14995      E24995      Susan    Harvey  Female    Illinois      Chicago
# 14996      E24996    Lindsay      Bell    Male    Illinois  Springfield
# 14997      E24997       Jose     Black  Female    Illinois      Chicago
# 14998      E24998       Lynn  Gonzalez  Female  California  Los Angeles
#
#                   Job Title Education Level  Birth Date   Hire Date  ...  \
# ...

# %%
df_emp.shape
# Out:
# (14999, 22)

# %% [markdown]
# # Understanding the Dataset

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee ID            14999 non-null  object
#  1   First Name             14999 non-null  object
#  2   Last Name              14999 non-null  object
#  3   Gender                 14999 non-null  object
#  4   State                  14999 non-null  object
#  5   City                   14999 non-null  object
#  6   Job Title              14999 non-null  object
#  7   Education Level        14999 non-null  object
#  8   Birth Date             14999 non-null  object
#  9   Hire Date              14999 non-null  object
#  10  salary                 14999 non-null  object
#  11  Actual Salary          14999 non-null  int64
#  12  Department             14999 non-null  object
#  13  promotion_last_5years  14999 non-null  int64
# ...

# %%
df_emp['Department'].value_counts()
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
df_emp['promotion_last_5years'].value_counts()
# Out:
# promotion_last_5years
# 0    14680
# 1      319
# Name: count, dtype: int64

# %%
df_emp.dtypes.value_counts()
# Out:
# object     13
# int64       7
# float64     2
# Name: count, dtype: int64

# %% [markdown]
# ## 1. Checking the data quality

# %%
df_emp.isna().sum(axis = 0)
# Out:
# Employee ID                 0
# First Name                  0
# Last Name                   0
# Gender                      0
# State                       0
#                         ...
# average_montly_hours        0
# time_spend_company          0
# Work_accident               0
# left                        0
# Termination Date        13315
# Length: 22, dtype: int64

# %% [markdown]
# # 2. Performing EDA to find out what factors contributed the most to employee turnover.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_emp.columns
# Out:
# Index(['Employee ID', 'First Name', 'Last Name', 'Gender', 'State', 'City',
#        'Job Title', 'Education Level', 'Birth Date', 'Hire Date', 'salary',
#        'Actual Salary', 'Department', 'promotion_last_5years',
#        'satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'Termination Date'],
#       dtype='object')

# %%
df_emp['Work_accident'].unique()
df_emp['number_project'].unique()
df_emp['time_spend_company'].unique()
df_emp['last_evaluation'].unique()
# Out:
# array([0.53, 0.86, 0.88, 0.87, 0.52, 0.5 , 0.77, 0.85, 1.  , 0.54, 0.81,
#        0.92, 0.55, 0.56, 0.47, 0.99, 0.51, 0.89, 0.83, 0.95, 0.57, 0.49,
#        0.46, 0.62, 0.94, 0.48, 0.8 , 0.74, 0.7 , 0.78, 0.91, 0.93, 0.98,
#        0.97, 0.79, 0.59, 0.84, 0.45, 0.96, 0.68, 0.82, 0.9 , 0.71, 0.6 ,
#        0.65, 0.58, 0.72, 0.67, 0.75, 0.73, 0.63, 0.61, 0.76, 0.66, 0.69,
#        0.37, 0.64, 0.39, 0.41, 0.43, 0.44, 0.36, 0.38, 0.4 , 0.42])

# %%
df_emp = df_emp.set_index('Employee ID')
df_emp
# Out:
#             First Name Last Name  Gender       State         City  \
# Employee ID
# E10000           Aaron      Soto  Female     Florida        Tampa
# E10001           Bruce   Estrada  Female    Illinois   Naperville
# E10002           Linda     Wells    Male    Illinois  Springfield
# E10003          Austin   Roberts    Male    New York      Buffalo
# E10004         Tiffany     Mason  Female     Florida        Miami
# ...                ...       ...     ...         ...          ...
# E24994          Alexis   Schultz  Female       Texas       Dallas
# E24995           Susan    Harvey  Female    Illinois      Chicago
# E24996         Lindsay      Bell    Male    Illinois  Springfield
# E24997            Jose     Black  Female    Illinois      Chicago
# E24998            Lynn  Gonzalez  Female  California  Los Angeles
#
#                         Job Title Education Level  Birth Date   Hire Date  \
# Employee ID
# ...

# %%
# finding correlartion between differect numeric columns
df_emp_corr = df_emp.select_dtypes(include=["number"]).corr()
df_emp_corr
# Out:
#                        Actual Salary  promotion_last_5years  \
# Actual Salary               1.000000               0.088020
# promotion_last_5years       0.088020               1.000000
# satisfaction_level          0.044730               0.025605
# last_evaluation            -0.011696              -0.008684
# number_project             -0.002394              -0.006064
# average_montly_hours       -0.004197              -0.003544
# time_spend_company          0.049373               0.067433
# Work_accident               0.001200               0.039245
# left                       -0.147050              -0.061788
#
#                        satisfaction_level  last_evaluation  number_project  \
# Actual Salary                    0.044730        -0.011696       -0.002394
# promotion_last_5years            0.025605        -0.008684       -0.006064
# satisfaction_level               1.000000         0.105021       -0.142970
# ...

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14999 entries, E10000 to E24998
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   First Name             14999 non-null  object
#  1   Last Name              14999 non-null  object
#  2   Gender                 14999 non-null  object
#  3   State                  14999 non-null  object
#  4   City                   14999 non-null  object
#  5   Job Title              14999 non-null  object
#  6   Education Level        14999 non-null  object
#  7   Birth Date             14999 non-null  object
#  8   Hire Date              14999 non-null  object
#  9   salary                 14999 non-null  object
#  10  Actual Salary          14999 non-null  int64
#  11  Department             14999 non-null  object
#  12  promotion_last_5years  14999 non-null  int64
#  13  satisfaction_level     14999 non-null  float64
# ...

# %%
df_emp['Termination Date'] = pd.to_datetime(df_emp['Termination Date'],format = "%d-%m-%Y")
df_emp['Termination Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 14999 entries, E10000 to E24998
# Series name: Termination Date
# Non-Null Count  Dtype
# --------------  -----
# 1684 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 234.4+ KB

# %%
# plt.figure(figsize = (10,10))
# sns.heatmap(df_emp_corr.corr(),annot = True)
# plt.figure(figsize=(7,7))
# sns.heatmap(df_emp_corr, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
# plt.title("Correlation Heatmap", fontsize=14)
# plt.show()

plt.figure(figsize=(12,8))
sns.heatmap(df_emp_corr.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From the correlation matrix it is seen that last_evalustion, number_project , average_monthly_hours has a relation with each other . and time_spend in a country is directly related to our target variable.

# %%
df_emp["Department"].value_counts()
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
df_emp['left'] = df_emp['left'].astype(str)

# %%
# to get department wise attrition
df_1 = df_emp.groupby(["Department"])['left'].value_counts().reset_index(name = "Count")

# %%
plt.figure(figsize=(8,8))
sns.barplot(x = 'Department',y = 'Count',hue = 'left',data=df_1 )
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# By looking at the graph above the most attrition happened in sales , support , technical then IT and least happend in HR

# %%
df_2 = df_emp["Department"].value_counts().reset_index(name = "Total")
# df_2.columns=['Department','Total']
df_2
# Out:
#     Department  Total
# 0        sales   4140
# 1    technical   2720
# 2      support   2229
# 3           IT   1227
# 4  product_mng    902
# 5    marketing    858
# 6        RandD    787
# 7   accounting    767
# 8           hr    739
# 9   management    630

# %%
# merging the two df to visualize attrition department wise
df_merge = df_1.merge(df_2,how = "left")
df_merge
# Out:
#      Department left  Count  Total
# 0            IT    0    954   1227
# 1            IT    1    273   1227
# 2         RandD    0    666    787
# 3         RandD    1    121    787
# 4    accounting    0    563    767
# 5    accounting    1    204    767
# 6            hr    0    524    739
# 7            hr    1    215    739
# 8    management    0    539    630
# 9    management    1     91    630
# 10    marketing    0    655    858
# 11    marketing    1    203    858
# 12  product_mng    0    704    902
# 13  product_mng    1    198    902
# 14        sales    0   3126   4140
# 15        sales    1   1014   4140
# 16      support    0   1674   2229
# 17      support    1    555   2229
# 18    technical    0   2023   2720
# 19    technical    1    697   2720

# %%
df_merge['per_of_total'] = df_merge['Count']/df_merge['Total']
df_merge['per_of_total'] = round(df_merge['per_of_total'] * 100,2)
df_merge
# Out:
#      Department left  Count  Total  per_of_total
# 0            IT    0    954   1227         77.75
# 1            IT    1    273   1227         22.25
# 2         RandD    0    666    787         84.63
# 3         RandD    1    121    787         15.37
# 4    accounting    0    563    767         73.40
# 5    accounting    1    204    767         26.60
# 6            hr    0    524    739         70.91
# 7            hr    1    215    739         29.09
# 8    management    0    539    630         85.56
# 9    management    1     91    630         14.44
# 10    marketing    0    655    858         76.34
# 11    marketing    1    203    858         23.66
# 12  product_mng    0    704    902         78.05
# 13  product_mng    1    198    902         21.95
# 14        sales    0   3126   4140         75.51
# 15        sales    1   1014   4140         24.49
# 16      support    0   1674   2229         75.10
# 17      support    1    555   2229         24.90
# ...

# %%
plt.figure(figsize=(5,5)) # 1 means left 
sns.barplot(x='Department',y='per_of_total',hue='left',data=df_merge)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# according to the above graph HR dept has the most no.of employees who left among all the departments.

# %%
df_emp.columns
# Out:
# Index(['First Name', 'Last Name', 'Gender', 'State', 'City', 'Job Title',
#        'Education Level', 'Birth Date', 'Hire Date', 'salary', 'Actual Salary',
#        'Department', 'promotion_last_5years', 'satisfaction_level',
#        'last_evaluation', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'Termination Date'],
#       dtype='object')

# %%
sns.histplot(data = df_emp , x = 'satisfaction_level' , kde = True , bins = 20)
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='Count'>

# %% [markdown]
# It can be inferred that most employees are satisfied

# %%
sns.histplot(data=df_emp,x='average_montly_hours',kde=True,bins=20)
# Out:
# <Axes: xlabel='average_montly_hours', ylabel='Count'>

# %%
df_sal = df_emp.groupby(['salary'])['left'].value_counts().reset_index(name = "count")
df_sal
# Out:
#    salary left  count
# 0    high    0   1155
# 1    high    1     82
# 2     low    0   5144
# 3     low    1   2172
# 4  medium    0   5129
# 5  medium    1   1317

# %%
plt.figure(figsize=(5,5))
sns.barplot(x = 'salary',y = 'count',hue = 'left', data = df_sal)
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %% [markdown]
# low salary is one of the main reason to leave the job.
